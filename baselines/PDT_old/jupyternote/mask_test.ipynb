# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
etth1_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_96_R2Linear_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm/A_matrices/layer_0_A.npy')
etth1_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_96_R2Linear_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm/A_matrices/layer_1_A.npy')

# %%
etth1_attn_nomask_96_0.shape, etth1_attn_nomask_96_1.shape
# Out:
# ((7, 7), (7, 7))

# %%
etth1_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_96_R2Linear_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_mask/A_matrices/layer_0_A.npy')
etth1_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_96_R2Linear_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_mask/A_matrices/layer_1_A.npy')
etth1_attn_mask_96_0.shape, etth1_attn_mask_96_1.shape
# Out:
# ((7, 7), (7, 7))

# %%
etth1_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_96_R2Linear_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_mask/channel_mask.npy')
etth1_mask_96 = np.squeeze(etth1_mask_96, axis=(0, 1))
etth1_mask_96.shape
# Out:
# (7, 7)

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(etth1_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('etth1_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(etth1_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('etth1_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(etth1_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('etth1_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(etth1_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('etth1_attn_mask_96_1')
axes[1][1].set_xlabel('Head')   
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(etth1_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('etth1_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(etth1_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('etth1_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()

# %%
weather_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm/A_matrices/layer_0_A.npy')
weather_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm/A_matrices/layer_1_A.npy')
weather_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
weather_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
weather_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
weather_mask_96 = np.squeeze(weather_mask_96, axis=(0, 1))

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(weather_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('weather_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(weather_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('weather_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(weather_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('weather_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(weather_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('weather_attn_mask_96_1')
axes[1][1].set_xlabel('Head')   
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(weather_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('weather_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(weather_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('weather_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()

# %%
ecl_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_EU-mask/A_matrices/layer_0_A.npy')
ecl_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_EU-mask/A_matrices/layer_1_A.npy')
ecl_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_EU-mask/A_matrices/layer_0_A.npy')
ecl_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_EU-mask/A_matrices/layer_1_A.npy')
ecl_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_EU-mask/channel_mask.npy')
ecl_mask_96 = np.squeeze(ecl_mask_96, axis=(0, 1))

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(ecl_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('ecl_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(ecl_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('ecl_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(ecl_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('ecl_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(ecl_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('ecl_attn_mask_96_1')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(ecl_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('ecl_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(ecl_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('ecl_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()

# %%
ratio_gt_half = np.mean(ecl_mask_96 > 0.5)
ratio_gt_half
# Out:
# 0.41255422598771363

# %%
ecl_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
ecl_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
ecl_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
ecl_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
ecl_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
ecl_mask_96 = np.squeeze(ecl_mask_96, axis=(0, 1))

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(ecl_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('ecl_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(ecl_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('ecl_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(ecl_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('ecl_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(ecl_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('ecl_attn_mask_96_1')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(ecl_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('ecl_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(ecl_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('ecl_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ecl_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
#       2 ecl_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
# ...

# %%
traffic_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
traffic_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
traffic_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_0_A.npy')
traffic_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/A_matrices/layer_1_A.npy')
traffic_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
traffic_mask_96 = np.squeeze(traffic_mask_96, axis=(0, 1))

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(traffic_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('traffic_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(traffic_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('traffic_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(traffic_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('traffic_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(traffic_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('traffic_attn_mask_96_1')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('traffic_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('traffic_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()

# %%
ratio_gt_half = np.mean(traffic_mask_96 > 0.5)
ratio_gt_half
# Out:
# 0.17384973164442483

# %%
traffic_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/A_matrices/layer_0_A.npy')
traffic_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/A_matrices/layer_1_A.npy')
traffic_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/A_matrices/layer_0_A.npy')
traffic_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/A_matrices/layer_1_A.npy')
traffic_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
traffic_mask_96 = np.squeeze(traffic_mask_96, axis=(0, 1))

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(traffic_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('traffic_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(traffic_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('traffic_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(traffic_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('traffic_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(traffic_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('traffic_attn_mask_96_1')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('traffic_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('traffic_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()

# %%
ratio_gt_half = np.mean(traffic_mask_96 > 0.5)
ratio_gt_half
# Out:
# 0.09524873358778214

# %%
traffic_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_0_A.npy')
traffic_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_1_A.npy')
traffic_attn_mask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_0_A.npy')
traffic_attn_mask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_1_A.npy')
traffic_mask_96 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/channel_mask.npy')
traffic_mask_96 = np.squeeze(traffic_mask_96, axis=(0, 1))

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

im0 = axes[0][0].imshow(traffic_attn_nomask_96_0, cmap='viridis', aspect='auto')
axes[0][0].set_title('traffic_attn_nomask_96_0')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(traffic_attn_nomask_96_1, cmap='viridis', aspect='auto')
axes[0][1].set_title('traffic_attn_nomask_96_1')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(traffic_attn_mask_96_0, cmap='viridis', aspect='auto')
axes[1][0].set_title('traffic_attn_mask_96_0')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(traffic_attn_mask_96_1, cmap='viridis', aspect='auto')
axes[1][1].set_title('traffic_attn_mask_96_1')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

im4 = axes[2][0].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][0].set_title('traffic_mask_96')
axes[2][0].set_xlabel('Channel')
axes[2][0].set_ylabel('Sequence')
fig.colorbar(im4, ax=axes[2][0])

im5 = axes[2][1].imshow(traffic_mask_96, cmap='viridis', aspect='auto')
axes[2][1].set_title('traffic_mask_96')
axes[2][1].set_xlabel('Channel')
axes[2][1].set_ylabel('Sequence')
fig.colorbar(im5, ax=axes[2][1])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 traffic_attn_nomask_96_0 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_0_A.npy')
#       2 traffic_attn_nomask_96_1 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-mask/A_matrices/layer_1_A.npy')
# ...

# %%
etth1_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_192_R2Linear_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_mask/channel_mask.npy')
etth1_mask = np.squeeze(etth1_mask, axis=(0, 1))
etth1_k_EU_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_192_R2Linear_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
etth1_k_EU_mask = np.squeeze(etth1_k_EU_mask, axis=(0, 1))
etth1_k_EU_mask_01 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ETTh1/results/long_term_forecast_ETTh1_96_192_R2Linear_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask-0.1/channel_mask.npy')
etth1_k_EU_mask_01 = np.squeeze(etth1_k_EU_mask_01, axis=(0, 1))
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

im0 = axes[0][0].imshow(etth1_mask, cmap='viridis', aspect='auto')
axes[0][0].set_title('etth1_mask')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(etth1_k_EU_mask, cmap='viridis', aspect='auto')
axes[0][1].set_title('etth1_k_EU_mask')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(etth1_k_EU_mask_01, cmap='viridis', aspect='auto')
axes[1][0].set_title('etth1_k_EU_mask_01')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])


plt.tight_layout()
plt.show()

# %%
weather_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
weather_mask = np.squeeze(weather_mask, axis=(0, 1))
weather_k_EU_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
weather_k_EU_mask = np.squeeze(weather_k_EU_mask, axis=(0, 1))
weather_k_EU_mask_01 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_weather/results/long_term_forecast_weather_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask-0.1/channel_mask.npy')
weather_k_EU_mask_01 = np.squeeze(weather_k_EU_mask_01, axis=(0, 1))
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

im0 = axes[0][0].imshow(weather_mask, cmap='viridis', aspect='auto')
axes[0][0].set_title('weather_mask')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(weather_k_EU_mask, cmap='viridis', aspect='auto')
axes[0][1].set_title('weather_k_EU_mask')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(weather_k_EU_mask_01, cmap='viridis', aspect='auto')
axes[1][0].set_title('weather_k_EU_mask_01')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])


plt.tight_layout()
plt.show()

# %%
ratio_weather_mask = np.mean(weather_mask > 0.5)
print("Ratio of weather_mask > 0.5:", ratio_weather_mask)
ratio_weather_k_EU_mask = np.mean(weather_k_EU_mask > 0.5)
print("Ratio of weather_k_EU_mask > 0.5:", ratio_weather_k_EU_mask)
ratio_weather_k_EU_mask_01 = np.mean(weather_k_EU_mask_01 > 0.5)
print("Ratio of weather_k_EU_mask_01 > 0.5:", ratio_weather_k_EU_mask_01)
# Out:
# Ratio of weather_mask > 0.5: 0.2947845804988662
# Ratio of weather_k_EU_mask > 0.5: 0.2108843537414966
# Ratio of weather_k_EU_mask_01 > 0.5: 0.3310657596371882

# %%
ecl_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
ecl_mask = np.squeeze(ecl_mask, axis=(0, 1))
ecl_k_EU_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
ecl_k_EU_mask = np.squeeze(ecl_k_EU_mask, axis=(0, 1))
ecl_k_EU_mask_01 = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_ECL/results/long_term_forecast_ECL_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask-0.1/channel_mask.npy')
ecl_k_EU_mask_01 = np.squeeze(ecl_k_EU_mask_01, axis=(0, 1))
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

im0 = axes[0][0].imshow(ecl_mask, cmap='viridis', aspect='auto')
axes[0][0].set_title('ecl_mask')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(ecl_k_EU_mask, cmap='viridis', aspect='auto')
axes[0][1].set_title('ecl_k_EU_mask')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(ecl_k_EU_mask_01, cmap='viridis', aspect='auto')
axes[1][0].set_title('ecl_k_EU_mask_01')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])


plt.tight_layout()
plt.show()

# %%
ratio_ecl_mask = np.mean(ecl_mask > 0.5)
print("Ratio of ecl_mask > 0.5:", ratio_ecl_mask)
ratio_ecl_k_EU_mask = np.mean(ecl_k_EU_mask > 0.5)
print("Ratio of ecl_k_EU_mask > 0.5:", ratio_ecl_k_EU_mask)
ratio_ecl_k_EU_mask_01 = np.mean(ecl_k_EU_mask_01 > 0.5)
print("Ratio of ecl_k_EU_mask_01 > 0.5:", ratio_ecl_k_EU_mask_01)
# Out:
# Ratio of ecl_mask > 0.5: 0.38738948573868653
# Ratio of ecl_k_EU_mask > 0.5: 0.21852466493919895
# Ratio of ecl_k_EU_mask_01 > 0.5: 0.3189507089411011

# %%
import numpy as np
import matplotlib.pyplot as plt
traffic_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
traffic_mask = np.squeeze(traffic_mask, axis=(0, 1))
traffic_k_EU_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
traffic_k_EU_mask = np.squeeze(traffic_k_EU_mask, axis=(0, 1))
traffic_k_EU_sig025mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_sig0.25mask/channel_mask.npy')
traffic_k_EU_sig025mask = np.squeeze(traffic_k_EU_sig025mask, axis=(0, 1))
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

im0 = axes[0][0].imshow(traffic_mask, cmap='viridis', aspect='auto')
axes[0][0].set_title('traffic_mask')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(traffic_k_EU_mask, cmap='viridis', aspect='auto')
axes[0][1].set_title('traffic_k_EU_mask')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(traffic_k_EU_sig025mask, cmap='viridis', aspect='auto')
axes[1][0].set_title('traffic_k_EU_sig025mask')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
traffic_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_Mask/channel_mask.npy')
traffic_mask = np.squeeze(traffic_mask, axis=(0, 1))
traffic_k_EU_mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-mask/channel_mask.npy')
traffic_k_EU_mask = np.squeeze(traffic_k_EU_mask, axis=(0, 1))
traffic_k_EU_sig015mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-sig0.15mask/channel_mask.npy')
traffic_k_EU_sig015mask = np.squeeze(traffic_k_EU_sig015mask, axis=(0, 1))
traffic_k_EU_sig01mask = np.load('/home/yingch/FreDF-main/exp_results/R2Linear/R2Linear_traffic/results/long_term_forecast_traffic_96_96_R2Linear_custom_ftM_sl96_ll48_pl96_dm512_nh8_el3_dl1_df512_fc3_ebtimeF_dtTrue_rr96_frR0_k16_Exp_0.1a_Rk_Dnorm_k-EU-sig0.1mask/channel_mask.npy')
traffic_k_EU_sig01mask = np.squeeze(traffic_k_EU_sig01mask, axis=(0, 1))
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

im0 = axes[0][0].imshow(traffic_mask, cmap='viridis', aspect='auto')
axes[0][0].set_title('traffic_mask')
axes[0][0].set_xlabel('Head')
axes[0][0].set_ylabel('Sequence')
fig.colorbar(im0, ax=axes[0][0])

im1 = axes[0][1].imshow(traffic_k_EU_mask, cmap='viridis', aspect='auto')
axes[0][1].set_title('traffic_k_EU_mask')
axes[0][1].set_xlabel('Head')
axes[0][1].set_ylabel('Sequence')
fig.colorbar(im1, ax=axes[0][1])

im2 = axes[1][0].imshow(traffic_k_EU_sig015mask, cmap='viridis', aspect='auto')
axes[1][0].set_title('traffic_k_EU_sig015mask')
axes[1][0].set_xlabel('Head')
axes[1][0].set_ylabel('Sequence')
fig.colorbar(im2, ax=axes[1][0])

im3 = axes[1][1].imshow(traffic_k_EU_sig01mask, cmap='viridis', aspect='auto')
axes[1][1].set_title('traffic_k_EU_sig01mask')
axes[1][1].set_xlabel('Head')
axes[1][1].set_ylabel('Sequence')
fig.colorbar(im3, ax=axes[1][1])

plt.tight_layout()
plt.show()

# %%
ratio_traffic_mask = np.mean(traffic_mask > 0.5)
print("Ratio of traffic_mask > 0.5:", ratio_traffic_mask)
ratio_traffic_k_EU_mask = np.mean(traffic_k_EU_mask > 0.5)
print("Ratio of traffic_k_EU_mask > 0.5:", ratio_traffic_k_EU_mask)
ratio_traffic_k_EU_mask_01 = np.mean(traffic_k_EU_sig015mask > 0.5)
print("Ratio of traffic_k_EU_mask_01 > 0.5:", ratio_traffic_k_EU_mask_01)
ratio_traffic_k_EU_mask_02 = np.mean(traffic_k_EU_sig01mask > 0.5)
print("Ratio of traffic_k_EU_mask_02 > 0.5:", ratio_traffic_k_EU_mask_02)
# Out:
# Ratio of traffic_mask > 0.5: 0.17384973164442483
# Ratio of traffic_k_EU_mask > 0.5: 0.09524873358778214
# Ratio of traffic_k_EU_mask_01 > 0.5: 0.179706719925065
# Ratio of traffic_k_EU_mask_02 > 0.5: 0.27358406769989396
